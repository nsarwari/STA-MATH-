# %% [markdown]
# Question 1 (compulsory):
# The quantity of items sold varies per transaction. TTR would like to know what the probability is that a
# transaction contains more than 2 items sold. Report and explain your analysis and conclusion.

# %%
import numpy as np

# %%
import pandas as pd

# %%
dataset_path = 'dataset_1668303.csv'

# %%
data = pd.read_csv (dataset_path)

# %%
more_than_two_items = data[data['transaction_qty'] > 2].shape[0]
print ("more_than_two_items:", more_than_two_items )
# Out:
# more_than_two_items: 1435

# %%
total_transactions = data.shape[0]
print ("total_transactions:", total_transactions )
# Out:
# total_transactions: 7356

# %%
probability = more_than_two_items / total_transactions * 100

# %%
print(f"The probability that a transaction contains more than 2 items sold is: {probability:.4f}")
# Out:
# The probability that a transaction contains more than 2 items sold is: 19.5079

# %% [markdown]
# Conclusion:
# The analysis revealed that about 19.5% of transactions in the dataset contain more than 2 items sold. This means that if you were to randomly select a transaction from this dataset, there's roughly a 1 in 5 chance that this transaction would include more than 2 items. This information can be useful for understanding purchasing behavior, inventory management, and sales strategies. It highlights a pattern of purchasing behavior that could be critical for business decisions, such as stocking levels, promotions, and marketing strategies aimed at increasing the average number of items per transaction.

# %% [markdown]
# Question 2 (compulsory):
# TTR would like to obtain insight in how the unit price varies for the product types that they sell. Conduct
# appropriate analysis, report relevant descriptive statistics and use visualizations when reporting your
# findings. Include skewness in your interpretation.

# %%
(3.0 + 3.75 + 3.15 + 4.5+ 6.3+ 3.5 + 3.25 + 2.0 + 4.25)/9
# Out:
# 3.744444444444445

# %% [markdown]
# 3.74 = mean

# %%
numbers = [3.0 , 3.75 , 3.15 ,  4.5 , 6.3 ,  3.5 , 3.25 , 2.0 , 4.25]

# %%
median2 = np.median (numbers)
print (median2)
# Out:
# 3.5

# %% [markdown]
# 3.5 = median

# %%
data['unit_price'].mean()
# Out:
# 3.789817835780315

# %%
data['unit_price'].median()
# Out:
# 3.5

# %% [markdown]
# I tried to get the median and mean in 2 ways just to double check. Out of these results we can say see that the mean is bigger than the median which means that the unit prices are right skewed.

# %% [markdown]
# measure of variation - range

# %%
import scipy.stats as st

# %%
import random

# %%
import plotly.express as px

# %%
import matplotlib.pyplot as plt

# %%
x_values =('unit_price')

# %%
y_values = ('product_type')

# %%
  box_plot = px.box(data, x='product_type', y='unit_price',
                      title="Box Plot of Unit Prices by Product Type")
if box_plot:
    box_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="00a9ef1e-b847-46f6-943c-a680e8b517a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00a9ef1e-b847-46f6-943c-a680e8b517a0")) {                    Plotly.newPlot(                        "00a9ef1e-b847-46f6-943c-a680e8b517a0",                        [{"alignmentgroup":"True","hovertemplate":"product_type=%{x}\u003cbr\u003eunit_price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Scone","Sandwich","Green tea","Hot chocolate","Organic blended coffee","Pie","Hot chocolate","Hot chocolate","Chai tea","Scone","Hot chocolate","Hot chocolate","Pie","Chai tea","Scone","Milk coffee","Hot chocolate","Green tea","Sandwich","Hot chocolate","Organic blended coffee","Green tea","Pie","Syrup coffee","Pie","Sandwich","Scone","Herbal tea","Black coffee","Hot chocolate","Pie","Black coffee","Chai tea","Organic blended coffee","Scone","Chai tea","Black tea","Pie","Scone","Black coffee","Scone","Syrup coffee","Black coffee","Hot chocolate","Hot chocolate","Black tea","Scone","Milk coffee","Green tea","Sandwich","Hot chocolate","Pie","Hot chocolate","Pie","Black tea","Scone","Organic blended coffee","Syrup coffee","Herbal tea","Hot chocolate","Black coffee","Green tea","Hot chocolate","Scone","Hot chocolate","Green tea","Green tea","Sandwich","Green tea","Hot chocolate","Milk coffee","Hot chocolate","Sandwich","Sandwich","Hot chocolate","Organic blended coffee","Black tea","Milk coffee","Herbal tea","Pie","Scone","Black tea","Herbal tea","Syrup coffee","Sandwich","Green tea","Organic blended coffee","Hot chocolate","Syrup coffee","Syrup coffee","Pie","Black tea","Sandwich","Sandwich","Organic blended coffee","Scone","Black coffee","Green tea","Herbal tea","Black coffee","Organic blended coffee","Milk coffee","Syrup coffee","Milk coffee","Pie","Hot chocolate","Hot chocolate","Herbal tea","Organic blended coffee","Scone","Sandwich","Scone","Pie","Pie","Hot chocolate","Herbal tea","Syrup coffee","Scone","Chai tea","Syrup coffee","Scone","Chai tea","Scone","Chai tea","Green tea","Hot chocolate","Black tea","Sandwich","Green tea","Hot chocolate","Pie","Black tea","Syrup coffee","Herbal tea","Herbal tea","Syrup coffee","Hot chocolate","Black coffee","Black coffee","Pie","Scone","Hot chocolate","Pie","Organic blended coffee","Organic blended coffee","Syrup coffee","Black tea","Pie","Black tea","Black tea","Sandwich","Organic blended coffee","Hot chocolate","Black tea","Sandwich","Milk coffee","Hot chocolate","Hot chocolate","Herbal tea","Pie","Milk coffee","Black coffee","Black coffee","Sandwich","Black tea","Hot chocolate","Hot chocolate","Black tea","Pie","Organic blended coffee","Herbal tea","Syrup coffee","Syrup coffee","Hot chocolate","Black coffee","Hot chocolate","Black tea","Chai tea","Milk coffee","Organic blended coffee","Sandwich","Black tea","Black tea","Organic blended coffee","Hot chocolate","Hot chocolate","Scone","Milk coffee","Green tea","Sandwich","Hot chocolate","Milk coffee","Syrup coffee","Black tea","Scone","Scone","Sandwich","Hot chocolate","Pie","Hot chocolate","Hot chocolate","Chai tea","Herbal tea","Hot chocolate","Hot chocolate","Hot chocolate","Organic blended coffee","Green tea","Black coffee","Hot chocolate","Black tea","Scone","Sandwich","Black coffee","Hot chocolate","Hot chocolate","Hot chocolate","Hot chocolate","Sandwich","Syrup coffee","Black coffee","Herbal tea","Hot chocolate","Hot chocolate","Sandwich","Pie","Black coffee","Green tea","Hot chocolate","Syrup coffee","Chai tea","Pie","Black tea","Hot chocolate","Hot chocolate","Black tea","Chai tea","Chai tea","Syrup coffee","Black  ...

# %%
px.histogram(data, x ='product_type' , y  = 'unit_price' ,title = "Histogram of unit prices by product type",nbins=20).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c372e5f4-edea-48db-b493-d1280b3cc2d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c372e5f4-edea-48db-b493-d1280b3cc2d4")) {                    Plotly.newPlot(                        "c372e5f4-edea-48db-b493-d1280b3cc2d4",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"product_type=%{x}\u003cbr\u003esum of unit_price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Scone","Sandwich","Green tea","Hot chocolate","Organic blended coffee","Pie","Hot chocolate","Hot chocolate","Chai tea","Scone","Hot chocolate","Hot chocolate","Pie","Chai tea","Scone","Milk coffee","Hot chocolate","Green tea","Sandwich","Hot chocolate","Organic blended coffee","Green tea","Pie","Syrup coffee","Pie","Sandwich","Scone","Herbal tea","Black coffee","Hot chocolate","Pie","Black coffee","Chai tea","Organic blended coffee","Scone","Chai tea","Black tea","Pie","Scone","Black coffee","Scone","Syrup coffee","Black coffee","Hot chocolate","Hot chocolate","Black tea","Scone","Milk coffee","Green tea","Sandwich","Hot chocolate","Pie","Hot chocolate","Pie","Black tea","Scone","Organic blended coffee","Syrup coffee","Herbal tea","Hot chocolate","Black coffee","Green tea","Hot chocolate","Scone","Hot chocolate","Green tea","Green tea","Sandwich","Green tea","Hot chocolate","Milk coffee","Hot chocolate","Sandwich","Sandwich","Hot chocolate","Organic blended coffee","Black tea","Milk coffee","Herbal tea","Pie","Scone","Black tea","Herbal tea","Syrup coffee","Sandwich","Green tea","Organic blended coffee","Hot chocolate","Syrup coffee","Syrup coffee","Pie","Black tea","Sandwich","Sandwich","Organic blended coffee","Scone","Black coffee","Green tea","Herbal tea","Black coffee","Organic blended coffee","Milk coffee","Syrup coffee","Milk coffee","Pie","Hot chocolate","Hot chocolate","Herbal tea","Organic blended coffee","Scone","Sandwich","Scone","Pie","Pie","Hot chocolate","Herbal tea","Syrup coffee","Scone","Chai tea","Syrup coffee","Scone","Chai tea","Scone","Chai tea","Green tea","Hot chocolate","Black tea","Sandwich","Green tea","Hot chocolate","Pie","Black tea","Syrup coffee","Herbal tea","Herbal tea","Syrup coffee","Hot chocolate","Black coffee","Black coffee","Pie","Scone","Hot chocolate","Pie","Organic blended coffee","Organic blended coffee","Syrup coffee","Black tea","Pie","Black tea","Black tea","Sandwich","Organic blended coffee","Hot chocolate","Black tea","Sandwich","Milk coffee","Hot chocolate","Hot chocolate","Herbal tea","Pie","Milk coffee","Black coffee","Black coffee","Sandwich","Black tea","Hot chocolate","Hot chocolate","Black tea","Pie","Organic blended coffee","Herbal tea","Syrup coffee","Syrup coffee","Hot chocolate","Black coffee","Hot chocolate","Black tea","Chai tea","Milk coffee","Organic blended coffee","Sandwich","Black tea","Black tea","Organic blended coffee","Hot chocolate","Hot chocolate","Scone","Milk coffee","Green tea","Sandwich","Hot chocolate","Milk coffee","Syrup coffee","Black tea","Scone","Scone","Sandwich","Hot chocolate","Pie","Hot chocolate","Hot chocolate","Chai tea","Herbal tea","Hot chocolate","Hot chocolate","Hot chocolate","Organic blended coffee","Green tea","Black coffee","Hot chocolate","Black tea","Scone","Sandwich","Black coffee","Hot chocolate","Hot chocolate","Hot chocolate","Hot chocolate","Sandwich","Syrup coffee","Black coffee","Herbal tea","Hot chocolate","Hot chocolate","Sandwich","Pie","Black coffee","Green tea","Hot chocolate","Syrup coffee","Chai tea","Pie","Black tea","Hot chocolate","Hot chocolate ...

# %%
import plotly.express as px

# %% [markdown]
# Based on the charts, the bulk of the data is concentrated towards the left of the distribution, and the tail extends to the right. This suggests a right-skewed (positively skewed) distribution. In a right-skewed distribution, the mean is typically greater than the median, and there may be a few unusually high values stretching out to the right.

# %% [markdown]
# Q3: TTR would like to obtain insight in the average revenue per transaction. Because you are working with
# sample data, they would like to also report the interval in which the real (population) average revenue
# per transaction is likely to fall. Report and explain your analysis and conclusion.

# %%
data ['revenue'] = data ['unit_price'] * data ['transaction_qty']

# %%
 (data.head)()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       06/11/2023         13:12:48              1.0
# 1               2       06/07/2023         14:45:20              2.0
# 2               3       06/10/2023         14:04:44              1.0
# 3               4       06/09/2023         07:47:50              2.0
# 4               5       06/10/2023         12:06:49              5.0
#
#    store_id store_location  unit_price product_category  \
# 0       2.0        Utrecht        3.00           Bakery
# 1       3.0      Eindhoven        3.75           Bakery
# 2       3.0      Eindhoven        3.15              Tea
# 3       3.0      Eindhoven        4.50        Chocolate
# 4       2.0        Utrecht        6.30           Coffee
#
#              product_type  revenue
# 0                   Scone     3.00
# 1                Sandwich     7.50
# 2               Green tea     3.15
# 3           Hot chocolate     9.00
# 4  Organic blended coffee    31.50

# %%
print("Total amount of transactions:", len(data))
# Out:
# Total amount of transactions: 7356

# %%
total_money_spent = (data['unit_price']* data["transaction_qty"]).sum()
print("Total amount of money spent:", total_money_spent )
print("Average revenue per transaction:", (total_money_spent/len(data)))
# Out:
# Total amount of money spent: 54680.100000000006
# Average revenue per transaction: 7.433401305057097

# %%
unit_price_per_date = data.groupby('transaction_date')["revenue"].sum()

# %%
print("The total amount of money spent per day:")
print(unit_price_per_date)
# Out:
# The total amount of money spent per day:
# transaction_date
# 06/05/2023     2780.75
# 06/06/2023     6211.40
# 06/07/2023     6353.65
# 06/08/2023     7727.30
# 06/09/2023    10423.15
# 06/10/2023    11596.25
# 06/11/2023     9587.60
# Name: revenue, dtype: float64

# %%
amount_of_transactions_per_day = data.groupby(data['transaction_date']).size()
print(amount_of_transactions_per_day)
# Out:
# transaction_date
# 06/05/2023     379
# 06/06/2023     799
# 06/07/2023     871
# 06/08/2023    1096
# 06/09/2023    1403
# 06/10/2023    1537
# 06/11/2023    1271
# dtype: int64

# %%
average_value06_05 = ( 2780.75 / 379 )
average_value06_06 = (6211.40 / 799)
average_value06_07 = (  6353.65 / 871 )
average_value06_08 = (7727.30 / 1096 )
average_value06_09 = (  10423.15 / 1403)
average_value06_10 = (11596.25 / 1537 )
average_value06_11 = ( 9587.60 / 1271 )

# %%
print ("average value per T 06/05:", average_value06_05)
print ("average value per T 06/06:", average_value06_06)
print ("average value per T 06/07:", average_value06_07)
print ("average value per T 06/08:", average_value06_08)
print ("average value per T 06/09:", average_value06_09)
print ("average value per T 06/10:", average_value06_10)
print ("average value per T 06/11:", average_value06_11)
# Out:
# average value per T 06/05: 7.337071240105541
# average value per T 06/06: 7.773967459324155
# average value per T 06/07: 7.294661308840413
# average value per T 06/08: 7.050456204379562
# average value per T 06/09: 7.429187455452602
# average value per T 06/10: 7.544729993493819
# average value per T 06/11: 7.5433516915814325

# %%
sample_mean = ( average_value06_05 + average_value06_06 + average_value06_07 + average_value06_08 + average_value06_09 + average_value06_10 + average_value06_11 ) / 7

# %%
print("sample mean:", sample_mean)
# Out:
# sample mean: 7.424775050453932

# %%
Average_value_perdays = average_value06_05 , average_value06_06, average_value06_07 , average_value06_08, average_value06_09, average_value06_10 , average_value06_11

# %%
std_deviation = np.std ( Average_value_perdays, ddof = 0)
print ("Standard deviation:", std_deviation)
# Out:
# Standard deviation: 0.2121793576010594

# %%
Confidence_interval = sample_mean + 1.96 * (std_deviation/7)
print ( Confidence_interval)
# Out:
# 7.484185270582229

# %% [markdown]
# Assignment 4

# %% [markdown]
# How well do different product
# types sell in terms of revenue?
# Are there product types that sell
# significantly worse than others?

# %%
data ['total_revenue'] = data ['transaction_qty'] * data ['unit_price']

# %%
revenue_by_producttype = data.groupby('product_type')['total_revenue'].sum().sort_values(ascending=False).reset_index()
print(revenue_by_producttype)
# Out:
#               product_type  total_revenue
# 0            Hot chocolate       16272.00
# 1   Organic blended coffee        5959.80
# 2                      Pie        4466.00
# 3                 Sandwich        4320.00
# 4             Syrup coffee        3633.75
# 5                    Scone        3474.00
# 6               Herbal tea        3300.50
# 7                 Chai tea        3068.00
# 8              Milk coffee        2947.00
# 9                Green tea        2857.05
# 10               Black tea        2778.00
# 11            Black coffee        1604.00

# %%
mean_revenue_by_producttype = (16272.00 + 5959.80 +4466.00+4320.00+ 3633.75+3474.00+3300.50+3068.00+2947.00+2857.05+2778.00 + 1604.00) / 12
print (mean_revenue_by_producttype)
# Out:
# 4556.675
